# %%
flag = True
items = []
metadata = {}

# %%
item_count = len(items)
key_count = len(metadata)

# %%
from flyteplugins.papermill import record_outputs

record_outputs(item_count=item_count, key_count=key_count)
