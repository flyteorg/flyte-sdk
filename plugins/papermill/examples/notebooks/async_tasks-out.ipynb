# %% [markdown]
# <span style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">An Exception was encountered at '<a href="#papermill-error-cell">In [4]</a>'.</span>

# %% [markdown]
# # Calling Async Flyte Tasks
#
# Jupyter supports top-level `await`, so you can call async Flyte tasks
# directly. When running remotely, these are submitted to Flyte.

# %%
a = 10.0
b = 20.0

# %%
# Parameters
b = 50.0
a = 20.0

# %% [markdown]
# <span id="papermill-error-cell" style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">Execution using papermill encountered an exception here and stopped:</span>

# %%
# Await async tasks — Jupyter supports top-level await
from async_example import async_add, async_double

doubled_a = await async_double(n=int(a))
doubled_b = await async_double(n=int(b))

result = await async_add(a=float(doubled_a), b=float(doubled_b))

print(f"double({a}) = {doubled_a}")
print(f"double({b}) = {doubled_b}")
print(f"add({doubled_a}, {doubled_b}) = {result}")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/Documents/Union/repos/flyte-sdk/src/flyte/_task.py:327, in TaskTemplate.__call__(self, *args, **kwargs)
#     325 from ._internal.controllers import get_controller
# --> 327 controller = get_controller()
#     328 if not controller:
#
# File ~/Documents/Union/repos/flyte-sdk/src/flyte/_internal/controllers/__init__.py:136, in get_controller()
#     135     return _ControllerState.controller
# --> 136 raise RuntimeError("Controller is not initialized. Please call create_controller() first.")
#
# RuntimeError: Controller is not initialized. Please call create_controller() first.
#
# The above exception was the direct cause of the following exception:
#
# RuntimeUserError                          Traceback (most recent call last)
# Cell In[4], line 4
#       1 # Await async tasks — Jupyter supports top-level await
# ...

# %%
from flyteplugins.papermill import record_outputs

record_outputs(result=result)
